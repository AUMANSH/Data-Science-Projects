# %% [markdown]
# <a href="https://colab.research.google.com/github/AUMANSH/Aumansh/blob/main/DA_experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("blog_dataset.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c6e728b3d2c4> in <cell line: 1>()
# ----> 1 df = pd.read_csv("blog_dataset.csv")
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#      Name  Age       City           State         DOB  Gender  \
# 0    Alam   29     Indore  Madhya Pradesh  20-11-1991    Male
# 1   Rohit   23  New Delhi           Delhi  19-09-1997    Male
# 2   Bimla   35     Rohtak         Haryana  09-01-1985  Female
# 3   Rahul   25    Kolkata     West Bengal  19-09-1995    Male
# 4  Chaman   32    Chennai      Tamil Nadu  12-03-1988    Male
#
#    City temperature  Salary
# 0              35.5   50000
# 1              39.0   85000
# 2              39.7   20000
# 3              36.5   40000
# 4              41.1   65000

# %%
df.head(7)
# Out:
#      Name  Age       City           State         DOB  Gender  \
# 0    Alam   29     Indore  Madhya Pradesh  20-11-1991    Male
# 1   Rohit   23  New Delhi           Delhi  19-09-1997    Male
# 2   Bimla   35     Rohtak         Haryana  09-01-1985  Female
# 3   Rahul   25    Kolkata     West Bengal  19-09-1995    Male
# 4  Chaman   32    Chennai      Tamil Nadu  12-03-1988    Male
# 5   Vivek   38   Gurugram         Haryana  22-06-1982    Male
# 6   Charu   29  New Delhi           Delhi  18-03-1992  Female
#
#    City temperature  Salary
# 0              35.5   50000
# 1              39.0   85000
# 2              39.7   20000
# 3              36.5   40000
# 4              41.1   65000
# 5              38.9   35000
# 6              39.0   52000

# %%
df.tail()
# Out:
#      Name  Age       City       State         DOB  Gender  City temperature  \
# 4  Chaman   32    Chennai  Tamil Nadu  12-03-1988    Male              41.1
# 5   Vivek   38   Gurugram     Haryana  22-06-1982    Male              38.9
# 6   Charu   29  New Delhi       Delhi  18-03-1992  Female              39.0
# 7  Ganesh   39      Patna       Bihar  07-12-1981    Male               NaN
# 8   Vivek   38   Gurugram     Haryana  22-06-1982    Male              38.9
#
#    Salary
# 4   65000
# 5   35000
# 6   52000
# 7   18000
# 8   35000

# %%
df.tail(7)
# Out:
#      Name  Age       City        State         DOB  Gender  City temperature  \
# 2   Bimla   35     Rohtak      Haryana  09-01-1985  Female              39.7
# 3   Rahul   25    Kolkata  West Bengal  19-09-1995    Male              36.5
# 4  Chaman   32    Chennai   Tamil Nadu  12-03-1988    Male              41.1
# 5   Vivek   38   Gurugram      Haryana  22-06-1982    Male              38.9
# 6   Charu   29  New Delhi        Delhi  18-03-1992  Female              39.0
# 7  Ganesh   39      Patna        Bihar  07-12-1981    Male               NaN
# 8   Vivek   38   Gurugram      Haryana  22-06-1982    Male              38.9
#
#    Salary
# 2   20000
# 3   40000
# 4   65000
# 5   35000
# 6   52000
# 7   18000
# 8   35000

# %%
df.describe()
# Out:
#              Age  City temperature        Salary
# count   9.000000          8.000000      9.000000
# mean   32.000000         38.575000  44444.444444
# std     5.894913          1.771803  21360.659582
# min    23.000000         35.500000  18000.000000
# 25%    29.000000         38.300000  35000.000000
# 50%    32.000000         38.950000  40000.000000
# 75%    38.000000         39.175000  52000.000000
# max    39.000000         41.100000  85000.000000

# %%
df['City'].describe()
# Out:
# count             9
# unique            7
# top       New Delhi
# freq              2
# Name: City, dtype: object

# %%
df.memory_usage(deep=True)
# Out:
# Index               128
# Name                559
# Age                  72
# City                578
# State               584
# DOB                 603
# Gender              553
# City temperature     72
# Salary               72
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              9 non-null      object
#  1   Age               9 non-null      int64
#  2   City              9 non-null      object
#  3   State             9 non-null      object
#  4   DOB               9 non-null      object
#  5   Gender            9 non-null      object
#  6   City temperature  8 non-null      float64
#  7   Salary            9 non-null      int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 704.0+ bytes

# %%
df['Gender'] = df.Gender.astype('category')
df
# Out:
#      Name  Age       City           State         DOB  Gender  \
# 0    Alam   29     Indore  Madhya Pradesh  20-11-1991    Male
# 1   Rohit   23  New Delhi           Delhi  19-09-1997    Male
# 2   Bimla   35     Rohtak         Haryana  09-01-1985  Female
# 3   Rahul   25    Kolkata     West Bengal  19-09-1995    Male
# 4  Chaman   32    Chennai      Tamil Nadu  12-03-1988    Male
# 5   Vivek   38   Gurugram         Haryana  22-06-1982    Male
# 6   Charu   29  New Delhi           Delhi  18-03-1992  Female
# 7  Ganesh   39      Patna           Bihar  07-12-1981    Male
# 8   Vivek   38   Gurugram         Haryana  22-06-1982    Male
#
#    City temperature  Salary
# 0              35.5   50000
# 1              39.0   85000
# 2              39.7   20000
# 3              36.5   40000
# 4              41.1   65000
# 5              38.9   35000
# 6              39.0   52000
# 7               NaN   18000
# 8              38.9   35000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              9 non-null      object
#  1   Age               9 non-null      int64
#  2   City              9 non-null      object
#  3   State             9 non-null      object
#  4   DOB               9 non-null      object
#  5   Gender            9 non-null      category
#  6   City temperature  8 non-null      float64
#  7   Salary            9 non-null      int64
# dtypes: category(1), float64(1), int64(2), object(4)
# memory usage: 765.0+ bytes

# %%
df.loc[0:4, ['Name', 'Age', 'State']]
# Out:
#      Name  Age           State
# 0    Alam   29  Madhya Pradesh
# 1   Rohit   23           Delhi
# 2   Bimla   35         Haryana
# 3   Rahul   25     West Bengal
# 4  Chaman   32      Tamil Nadu

# %%
df['DOB'] = pd.to_datetime(df['DOB'])
df
# Out:
#      Name  Age       City           State        DOB  Gender  \
# 0    Alam   29     Indore  Madhya Pradesh 1991-11-20    Male
# 1   Rohit   23  New Delhi           Delhi 1997-09-19    Male
# 2   Bimla   35     Rohtak         Haryana 1985-09-01  Female
# 3   Rahul   25    Kolkata     West Bengal 1995-09-19    Male
# 4  Chaman   32    Chennai      Tamil Nadu 1988-12-03    Male
# 5   Vivek   38   Gurugram         Haryana 1982-06-22    Male
# 6   Charu   29  New Delhi           Delhi 1992-03-18  Female
# 7  Ganesh   39      Patna           Bihar 1981-07-12    Male
# 8   Vivek   38   Gurugram         Haryana 1982-06-22    Male
#
#    City temperature  Salary
# 0              35.5   50000
# 1              39.0   85000
# 2              39.7   20000
# 3              36.5   40000
# 4              41.1   65000
# 5              38.9   35000
# 6              39.0   52000
# 7               NaN   18000
# 8              38.9   35000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              9 non-null      object
#  1   Age               9 non-null      int64
#  2   City              9 non-null      object
#  3   State             9 non-null      object
#  4   DOB               9 non-null      datetime64[ns]
#  5   Gender            9 non-null      category
#  6   City temperature  8 non-null      float64
#  7   Salary            9 non-null      int64
# dtypes: category(1), datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 765.0+ bytes

# %%
df['State'].value_counts()
# Out:
# Haryana           3
# Delhi             2
# Madhya Pradesh    1
# West Bengal       1
# Tamil Nadu        1
# Bihar             1
# Name: State, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      Name  Age       City           State        DOB  Gender  \
# 0    Alam   29     Indore  Madhya Pradesh 1991-11-20    Male
# 1   Rohit   23  New Delhi           Delhi 1997-09-19    Male
# 2   Bimla   35     Rohtak         Haryana 1985-09-01  Female
# 3   Rahul   25    Kolkata     West Bengal 1995-09-19    Male
# 4  Chaman   32    Chennai      Tamil Nadu 1988-12-03    Male
# 5   Vivek   38   Gurugram         Haryana 1982-06-22    Male
# 6   Charu   29  New Delhi           Delhi 1992-03-18  Female
# 7  Ganesh   39      Patna           Bihar 1981-07-12    Male
# 8   Vivek   38   Gurugram         Haryana 1982-06-22    Male
#
#    City temperature  Salary
# 0              35.5   50000
# 1              39.0   85000
# 2              39.7   20000
# 3              36.5   40000
# 4              41.1   65000
# 5              38.9   35000
# 6              39.0   52000
# 7               NaN   18000
# 8              38.9   35000

# %%
df.groupby('State').Salary.mean()
# Out:
# State
# Bihar             18000.0
# Delhi             68500.0
# Haryana           30000.0
# Madhya Pradesh    50000.0
# Tamil Nadu        65000.0
# West Bengal       40000.0
# Name: Salary, dtype: float64

# %%
df.sort_values('Name',inplace=True)

# %%
df
# Out:
#      Name  Age       City           State        DOB  Gender  \
# 0    Alam   29     Indore  Madhya Pradesh 1991-11-20    Male
# 1   Rohit   23  New Delhi           Delhi 1997-09-19    Male
# 2   Bimla   35     Rohtak         Haryana 1985-09-01  Female
# 3   Rahul   25    Kolkata     West Bengal 1995-09-19    Male
# 4  Chaman   32    Chennai      Tamil Nadu 1988-12-03    Male
# 5   Vivek   38   Gurugram         Haryana 1982-06-22    Male
# 6   Charu   29  New Delhi           Delhi 1992-03-18  Female
# 7  Ganesh   39      Patna           Bihar 1981-07-12    Male
# 8   Vivek   38   Gurugram         Haryana 1982-06-22    Male
#
#    City temperature  Salary
# 0              35.5   50000
# 1              39.0   85000
# 2              39.7   20000
# 3              36.5   40000
# 4              41.1   65000
# 5              38.9   35000
# 6              39.0   52000
# 7               NaN   18000
# 8              38.9   35000

# %%
df['City temperature'].describe()
# Out:
# count     8.000000
# mean     38.575000
# std       1.771803
# min      35.500000
# 25%      38.300000
# 50%      38.950000
# 75%      39.175000
# max      41.100000
# Name: City temperature, dtype: float64
